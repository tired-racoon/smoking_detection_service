# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
HOME = "/content/drive/MyDrive/SmokeDetection"
# !mkdir {HOME}

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="Fd8U0qs1VYNoZGpQvPBw")
project = rf.workspace("121-hsypi").project("smoking-gsusl")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# %cd {HOME}
# !ls datasets/Smoking-1/

# %%
# !yolo task=detect mode=train model=yolov11s.pt data={HOME}/datasets/Smoking-1/data.yaml epochs=50 imgsz=640 plots=True
